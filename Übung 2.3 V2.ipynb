# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.datasets import boston_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import matplotlib
import matplotlib.pyplot as plt # plotting library

# %%
# Laden
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()

# %%
# Normalisierung
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Erstellung
model = Sequential()

# %%
# Hinzufügen Neuronen und Aktivierungsfunktion
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))

# Hinzufügen einer Ausgabeschicht mit einem Neuron
model.add(Dense(1))

# %%
# Kompilieren
model.compile(loss='mean_squared_error',
               optimizer='adam',
               metrics=['accuracy'])

# %%
# Training
history = model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 1ms/step - loss: 590.6349 - accuracy: 0.0000e+00
# Epoch 2/100
# 13/13 [==============================] - 0s 1ms/step - loss: 565.9492 - accuracy: 0.0000e+00
# Epoch 3/100
# 13/13 [==============================] - 0s 1ms/step - loss: 542.3068 - accuracy: 0.0000e+00
# Epoch 4/100
# 13/13 [==============================] - 0s 1ms/step - loss: 518.1818 - accuracy: 0.0000e+00
# Epoch 5/100
# 13/13 [==============================] - 0s 1ms/step - loss: 493.4872 - accuracy: 0.0000e+00
# Epoch 6/100
# 13/13 [==============================] - 0s 1ms/step - loss: 467.9414 - accuracy: 0.0000e+00
# Epoch 7/100
# 13/13 [==============================] - 0s 1ms/step - loss: 441.7940 - accuracy: 0.0000e+00
# Epoch 8/100
# 13/13 [==============================] - 0s 1ms/step - loss: 413.9804 - accuracy: 0.0000e+00
# Epoch 9/100
# 13/13 [==============================] - 0s 1ms/step - loss: 385.7190 - accuracy: 0.0000e+00
# Epoch 10/100
# ...

# %%
# Evaluierung
mse = mean_squared_error(y_test, model.predict(x_test))
# Out:
# 4/4 [==============================] - 0s 997us/step

# %%
# Ausgabe MSE
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 22.899750697278595

# %%
#Evaluate the model against the test dataset and print results
print("\nEvaluation against Test Dataset :\n------------------------------------")
model.evaluate(x_test,y_test)
# Out:
# Evaluation against Test Dataset :
# ------------------------------------
# 4/4 [==============================] - 0s 2ms/step - loss: 22.8997 - accuracy: 0.0000e+00
# [22.899749755859375, 0.0]

# %%
#Modell 2
# Laden
(x_train2, y_train2), (x_test2, y_test2) = boston_housing.load_data()
# Normalisierung
scaler = StandardScaler()
x_train2 = scaler.fit_transform(x_train2)
x_test2 = scaler.transform(x_test2)
# Erstellung
model2 = Sequential()
# Hinzufügen Neuronen und Aktivierungsfunktion
model2.add(Dense(64, activation='sigmoid', input_shape=(x_train.shape[1],)))

# Hinzufügen einer Ausgabeschicht mit einem Neuron
model2.add(Dense(1))
# Kompilieren
model2.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])
# Training
history2 = model2.fit(x_train2, y_train2, epochs=100, batch_size=32)
# Evaluierung
mse2 = mean_squared_error(y_test2, model2.predict(x_test2))
# Ausgabe MSE
print("Mean Squared Error:", mse2)

#Evaluate the model against the test dataset and print results
print("\nEvaluation against Test Dataset :\n------------------------------------")
model2.evaluate(x_test2, y_test2)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 1ms/step - loss: 495.9471 - accuracy: 0.0000e+00
# Epoch 2/100
# 13/13 [==============================] - 0s 1ms/step - loss: 475.3377 - accuracy: 0.0000e+00
# Epoch 3/100
# 13/13 [==============================] - 0s 1ms/step - loss: 455.2222 - accuracy: 0.0000e+00
# Epoch 4/100
# 13/13 [==============================] - 0s 1ms/step - loss: 435.5603 - accuracy: 0.0000e+00
# Epoch 5/100
# 13/13 [==============================] - 0s 1ms/step - loss: 416.3372 - accuracy: 0.0000e+00
# Epoch 6/100
# 13/13 [==============================] - 0s 1ms/step - loss: 397.4261 - accuracy: 0.0000e+00
# Epoch 7/100
# 13/13 [==============================] - 0s 1ms/step - loss: 378.8452 - accuracy: 0.0000e+00
# Epoch 8/100
# 13/13 [==============================] - 0s 1ms/step - loss: 361.1601 - accuracy: 0.0000e+00
# Epoch 9/100
# 13/13 [==============================] - 0s 1ms/step - loss: 343.7131 - accuracy: 0.0000e+00
# Epoch 10/100
# ...

# %%
#Modell 3
# Laden
(x_train3, y_train3), (x_test3, y_test3) = boston_housing.load_data()
# Normalisierung
scaler = StandardScaler()
x_train3 = scaler.fit_transform(x_train3)
x_test3 = scaler.transform(x_test3)
# Erstellung
model3 = Sequential()
# Hinzufügen Neuronen und Aktivierungsfunktion
model3.add(Dense(250, activation='relu', input_shape=(x_train.shape[1],)))

# Hinzufügen einer Ausgabeschicht mit einem Neuron
model3.add(Dense(1))
# Kompilieren
model3.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])
# Training
history3 = model3.fit(x_train3, y_train3, epochs=100, batch_size=32)
# Evaluierung
mse3 = mean_squared_error(y_test3, model3.predict(x_test3))
# Ausgabe MSE
print("Mean Squared Error:", mse3)

#Evaluate the model against the test dataset and print results
print("\nEvaluation against Test Dataset :\n------------------------------------")
model3.evaluate(x_test3, y_test3)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 1ms/step - loss: 569.5125 - accuracy: 0.0000e+00
# Epoch 2/100
# 13/13 [==============================] - 0s 2ms/step - loss: 525.6022 - accuracy: 0.0000e+00
# Epoch 3/100
# 13/13 [==============================] - 0s 1ms/step - loss: 479.2756 - accuracy: 0.0000e+00
# Epoch 4/100
# 13/13 [==============================] - 0s 2ms/step - loss: 429.1408 - accuracy: 0.0000e+00
# Epoch 5/100
# 13/13 [==============================] - 0s 1ms/step - loss: 372.8030 - accuracy: 0.0000e+00
# Epoch 6/100
# 13/13 [==============================] - 0s 1ms/step - loss: 314.3470 - accuracy: 0.0000e+00
# Epoch 7/100
# 13/13 [==============================] - 0s 1ms/step - loss: 255.6654 - accuracy: 0.0000e+00
# Epoch 8/100
# 13/13 [==============================] - 0s 1ms/step - loss: 202.8156 - accuracy: 0.0000e+00
# Epoch 9/100
# 13/13 [==============================] - 0s 1ms/step - loss: 158.6590 - accuracy: 0.0000e+00
# Epoch 10/100
# ...

# %%
#Modell 4
# Laden
(x_train4, y_train4), (x_test4, y_test4) = boston_housing.load_data()
# Normalisierung
scaler = StandardScaler()
x_train4 = scaler.fit_transform(x_train4)
x_test4 = scaler.transform(x_test4)
# Erstellung
model4 = Sequential()
# Hinzufügen Neuronen und Aktivierungsfunktion
model4.add(Dense(250, activation='relu', input_shape=(x_train.shape[1],)))

# Hinzufügen einer Ausgabeschicht mit einem Neuron
model4.add(Dense(1))
# Kompilieren
model4.compile(loss='mean_squared_error',
              optimizer='SGD',
              metrics=['accuracy'])
# Training
history4 = model4.fit(x_train4, y_train4, epochs=100, batch_size=32)
# Evaluierung
mse4 = mean_squared_error(y_test4, model4.predict(x_test4))
# Ausgabe MSE
print("Mean Squared Error:", mse4)

#Evaluate the model against the test dataset and print results
print("\nEvaluation against Test Dataset :\n------------------------------------")
model4.evaluate(x_test4, y_test4)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 1ms/step - loss: 145.6660 - accuracy: 0.0000e+00
# Epoch 2/100
# 13/13 [==============================] - 0s 1ms/step - loss: 19.9830 - accuracy: 0.0000e+00
# Epoch 3/100
# 13/13 [==============================] - 0s 1ms/step - loss: 17.2272 - accuracy: 0.0000e+00
# Epoch 4/100
# 13/13 [==============================] - 0s 1ms/step - loss: 13.1583 - accuracy: 0.0000e+00
# Epoch 5/100
# 13/13 [==============================] - 0s 1ms/step - loss: 13.1777 - accuracy: 0.0000e+00
# Epoch 6/100
# 13/13 [==============================] - 0s 1ms/step - loss: 10.7069 - accuracy: 0.0000e+00
# Epoch 7/100
# 13/13 [==============================] - 0s 1ms/step - loss: 10.3070 - accuracy: 0.0000e+00
# Epoch 8/100
# 13/13 [==============================] - 0s 1ms/step - loss: 11.1915 - accuracy: 0.0000e+00
# Epoch 9/100
# 13/13 [==============================] - 0s 1ms/step - loss: 10.0333 - accuracy: 0.0000e+00
# Epoch 10/100
# ...

# %%
#Modell 5
# Laden
(x_train5, y_train5), (x_test5, y_test5) = boston_housing.load_data()
# Normalisierung
scaler = StandardScaler()
x_train5 = scaler.fit_transform(x_train5)
x_test5 = scaler.transform(x_test5)
# Erstellung
model5 = Sequential()
# Hinzufügen Neuronen und Aktivierungsfunktion
model5.add(Dense(250, activation='relu', input_shape=(x_train.shape[1],)))

# Hinzufügen einer Ausgabeschicht mit einem Neuron
model5.add(Dense(1))
# Kompilieren
model5.compile(loss='mean_squared_error',
              optimizer='SGD',
              metrics=['accuracy'])
# Training
history5 = model5.fit(x_train5, y_train5, epochs=100, batch_size=20)
# Evaluierung
mse5 = mean_squared_error(y_test5, model5.predict(x_test5))
# Ausgabe MSE
print("Mean Squared Error:", mse5)

#Evaluate the model against the test dataset and print results
print("\nEvaluation against Test Dataset :\n------------------------------------")
model5.evaluate(x_test5, y_test5)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 0s 1ms/step - loss: 116.7896 - accuracy: 0.0000e+00
# Epoch 2/100
# 21/21 [==============================] - 0s 1ms/step - loss: 20.9379 - accuracy: 0.0000e+00
# Epoch 3/100
# 21/21 [==============================] - 0s 1ms/step - loss: 14.8271 - accuracy: 0.0000e+00
# Epoch 4/100
# 21/21 [==============================] - 0s 1ms/step - loss: 12.6759 - accuracy: 0.0000e+00
# Epoch 5/100
# 21/21 [==============================] - 0s 1ms/step - loss: 14.5079 - accuracy: 0.0000e+00
# Epoch 6/100
# 21/21 [==============================] - 0s 1ms/step - loss: 11.7709 - accuracy: 0.0000e+00
# Epoch 7/100
# 21/21 [==============================] - 0s 1ms/step - loss: 11.0896 - accuracy: 0.0000e+00
# Epoch 8/100
# 21/21 [==============================] - 0s 1ms/step - loss: 10.8791 - accuracy: 0.0000e+00
# Epoch 9/100
# 21/21 [==============================] - 0s 2ms/step - loss: 9.5287 - accuracy: 0.0000e+00
# Epoch 10/100
# ...
